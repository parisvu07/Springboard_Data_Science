# %% [markdown]
# # 4 Modeling

# %% [markdown]
# The stock market is a focus for investors to maximize their potential profits and consequently, the interest shown from the technical and financial sides in stock market prediction is always on the rise.
#
# However, stock market prediction is a problem known for its challenging nature due to its dependency on diverse factors that affect the market, these factors are unpredictable and cannot be taken into consideration such as political variables, and social media effects such as twitter on the stock market.
#
# Text classification can be applied to many different problems, including gauging the public opinion on social media. Historically, it is studied as news articles classification into a pre-determined set of classes, and based on the summary or the title or even the whole body of the article the machine learning models determine if the news article is about economy, sports, real state, and so on. It can also be used for classifying a company's documents into categories that will be analyzed only by the corresponding department. Finally, it can direct, for example, quantify public opinions by classifying the query of a ticker, allowing to gauge public sentiments and lead to accurate price prediction.

# %% [markdown]
# ## 4.1 Prepping

# %% [markdown]
# ### 4.1.1 Importing

# %%
import os
import math 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#ignore warning messages to ensure clean outputs
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing stock data from previous notebook "03_Preprocessing_and_Training_Data"
eda_stock_data = pd.read_csv('/Users/user/Documents/Springboard_Data_Science/Capstone_2_Twitter_Sentiment_Analysis/Data/eda_stock_data.csv', encoding='latin-1')
eda_stock_data.reset_index(drop=True, inplace=True)
eda_stock_data.head()
# Out:
#         Dates      Time     Volume  %_change_Open  %_change_High  \
# 0  2022-10-03  00:00:00  114311700            NaN            NaN
# 1  2022-10-04  00:00:00   87830100       4.934514       2.201715
# 2  2022-10-05  00:00:00   79471000      -0.661926       0.793328
# 3  2022-10-06  00:00:00   68402200       1.207739       0.108555
# 4  2022-10-07  00:00:00   85925600      -2.242648      -3.009345
#
#    %_change_Low  %_change_Close  %_change_Volume
# 0           NaN             NaN              NaN
# 1      4.771583        2.562311       -23.166133
# 2     -0.866491        0.205326        -9.517352
# 3      1.545351       -0.662562       -13.928100
# 4     -3.973285       -3.671873        25.618182

# %%
#Importing tweet data from previous notebook "03_Preprocessing_and_Training_Data"
tweets = pd.read_csv('/Users/user/Documents/Springboard_Data_Science/Capstone_2_Twitter_Sentiment_Analysis/Data/tweets.csv', lineterminator='\n')
tweets.head()
# Out:
#         Dates      Time           user likes              source  \
# 0  2022-10-04  20:29:10  BarbaraDarlin     0   Tweetbot for iÎS
# 1  2022-10-04  20:29:03        Options     0      StockTwits Web
# 2  2022-10-04  20:27:59       IGSquawk     8           TweetDeck
# 3  2022-10-04  20:27:54    breckyunits     0     Twitter Web App
# 4  2022-10-04  20:27:11  emilesmithjoe     0  Twitter for iPhone
#
#                                                 text  Subjectivity  Polarity  \
# 0  .@apple needs to do this WORLDWIDE! https://t....      0.000000  0.000000
# 1  #HotOptions Report For End Of Day, October 4, ...      0.000000  0.000000
# 2  FANG+ Constituents:\n\n$AAPL 146.04 +2.52%\n$A...      0.000000  0.000000
# 3  I gave this talk in 2017 at @forwardJS . They ...      0.633333 -0.366667
# 4              @Apple make a cannon emoji. Thank you      0.000000  0.000000
#
#    Analysis  char_count  ...  \
# 0   Neutral          59  ...
# 1   Neutral         207  ...
# 2   Neutral         238  ...
# 3  Negative         229  ...
# 4   Neutral          37  ...
#
#                                          punct_count  avg_wordlength  \
# 0  {'! count': 1, '" count': 0, '# count': 0, '$ ...        8.428571
# 1  {'! count': 0, '" count': 0, '# count': 1, '$ ...        6.900000
# 2  {'! count': 0, '" count': 0, '# count': 0, '$ ...        6.800000
# 3  {'! count': 0, '" count': 2, '# count': 0, '$ ...        5.871795
# 4  {'! count': 0, '" count': 0, '# count': 0, '$ ...        5.285714
#
#    avg_sentlength  unique_vs_words  stopwords_vs_words  \
# 0        2.333333         1.000000            0.428571
# 1       30.000000         1.000000            0.000000
# 2       35.000000         1.000000            0.000000
# 3        9.750000         0.923077            0.384615
# 4        3.500000         1.000000            0.285714
#
#                                           clean_text  \
# 0    need  to do thi  worldwide  http  t co zlitq...
# 1   hotoption  report for end of day  october    ...
# 2  fang  con tituent  \n\n aapl      \n amzn     ...
# 3  i gave thi  talk in  at    they had it profe i...
# 4                     make a cannon emoji  thank you
#
#                                               tokens  \
# 0  ['need', 'to', 'do', 'thi', 'worldwide', 'http...
# 1  ['hotoption', 'report', 'for', 'end', 'of', 'd...
# 2  ['fang', 'con', 'tituent', 'aapl', 'amzn', 'ba...
# 3  ['i', 'gave', 'thi', 'talk', 'in', 'at', 'they...
# 4   ['make', 'a', 'cannon', 'emoji', 'thank', 'you']
#
#                              tweet_without_stopwords  \
# 0              need thi worldwide http co zlitq pich
# 1  hotoption report end day october â la aapl a...
# 2  fang con tituent aapl amzn baba bidu meta goog...
# 3  gave thi talk profe ionally recorded thought w...
# 4                            make cannon emoji thank
#
#                                     tweet_lemmatized  Sentiment
# 0  ['need', 'thi', 'worldwide', 'http', 'co', 'zl...          0
# 1  ['hotoption', 'report', 'end', 'day', 'october...          0
# 2  ['fang', 'con', 'tituent', 'aapl', 'amzn', 'ba...          0
# 3  ['gave', 'thi', 'talk', 'profe', 'ionally', 'r...         -1
# 4               ['make', 'cannon', 'emoji', 'thank']          0
#
# [5 rows x 26 columns]

# %% [markdown]
# ### 4.1.2 Combining dataframes
